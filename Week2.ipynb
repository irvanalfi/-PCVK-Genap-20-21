# %% [markdown]
# <a href="https://colab.research.google.com/github/irvanalfi/-PCVK-Genap-20-21/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')

#tampilan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax  = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik titik pt1 dan pt2
cv.rectangle(black_img, pt1 = (384, 0), pt2 = (510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1 = (200, 200), pt2 = (300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center = (100, 100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font= cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text = 'Hello', org=(10,500),fontFace=font, fontScale=4, color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
cv.circle(black_img,center=(400,400),radius=40,color=(255,0,0),thickness=-1)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

pts = vertices.reshape((-1,1,2))# nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts

cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   **Jawab :**
#
#   jika tidak menggunakan matplotib makan gambar tidak memiliki ruller di kiri dan kanan sebagai tolak ukur untu mengetahui seberapa ukuran gambar yang kita tampilkan
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32? Jawaban
#
#   **Jawab :**
#
#   perbedaan nya terletak pada ukuran file gambar yang di tampilkan. untuk int16 memiliki kapasitas yang lebih sedikit dari pada int32 yang memiliki kapasitas lebih banyak
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
#   pts = vertices.reshape((-1,1,2))
#
#   **Jawab :**
#
#   Angka -1, mengubah array menjadi array 3 dimensi. Angka 1 dan 2 memiliki arti setiap 1 baris array memiliki isi dua data
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
#
#   from google.colab.patches import cv2_imshow
#   from skimage import io
#
#   **Jawab :**
#
#   Perlu adanya Pacthes untuk digunakan sebagai perantara menampilkan gambar kita pada google colab
# 5. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3?
#
#   **Jawab :**
#
#   Untuk melakukan load, read, and Write sebuah gambar

# %% [markdown]
# # **Tugas**
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
#
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
# Blue Chanel di set 0
img[:, :, 0] = 0
plt.imshow(img)

# %%
# Red Chanel di set 0
img[:, :, 2] = 0
plt.imshow(img)

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100!

# %%
img_crop = img[10:100,10:100]
img_crop = cv.cvtColor(img_crop, cv.COLOR_BGR2RGB)
plt.imshow(img_crop)

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
img_crop = img[5:30,:]
img_crop[:, :, 0] = 0
img_crop[:, :, 2] = 0
plt.imshow(img_crop)

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random

# %%
import random as r

img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

n = 0
while(n < 5) :
  k1 = r.randint(0,1000)
  k2 = r.randint(0,1000)
  color1 = r.randint(0, 255)
  color2 = r.randint(0, 255)
  color3 = r.randint(0, 255)
  newImage = cv.rectangle(img, pt1=(k1,k1), pt2=(k2,k2), color=(color1,color2,color3), thickness=18)
  n+=1

plt.imshow(newImage)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
img = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
plt.imshow(img)

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut
# 1. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

cv.rectangle(img, pt1=(3000,400), pt2=(1200,1750), color=(255,255,0), thickness=30)
cv.circle(img, center=(2100, 1050), radius=800, color=(255,0,0), thickness=30)
plt.imshow(img)

# %% [markdown]
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_NM/Images/kitten01.jpg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

cv.rectangle(img, pt1=(50, 2680), pt2=(600, 2200), color=(0,100,255), thickness=30)
plt.imshow(img)
